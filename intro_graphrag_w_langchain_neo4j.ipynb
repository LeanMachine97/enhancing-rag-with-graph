# %% [markdown]
# # Introduction to Graph based RAG using LangChain and Neo4j
#
# Prereqs:
# * Python is installed in your machine
#
# * Run to create a separate virtual env for the project, disconnect VPN first:
# `conda create -n <YOUR_DESIRED_PYTHON_ENV_NAME>`
#
# * Run to switch to the created virtual env:
# `conda activate <YOUR_DESIRED_PYTHON_ENV_NAME>`
#
# * Run to install python packages in requirements.txt while avoiding SSL cert verify failed issue when installing
# `pip install -r requirements.txt --trusted-host pypi.org --trusted-host files.pythonhosted.org`
#
# * Install Neo4j Desktop and create a new database: [Neo4j Desktop download](https://neo4j.com/download/) (local instance). [How to create a new database](https://neo4j.com/docs/desktop-manual/current/operations/create-dbms/)
#
# * Install the [`APOC` plugin](https://neo4j.com/labs/apoc/4.1/installation/#neo4j-desktop)
#
# * Environment variables for `NEO4J_URI` (usually `bolt://localhost:7687` ), `NEO4J_PASSWORD`, `NEO4J_USERNAME`, and `OPENAI_API_KEY` should be set. The Neo4j URI, username, and password can be obtained from the Neo4j Desktop. The OpenAI API key can be obtained from your OpenAI account

# %% [markdown]
# ## Load libraries

# %%
# Set up the credentials
import os

os.environ["OPENAI_API_KEY"] = "<YOUR_OPENAI_APIKEY"
os.environ["NEO4J_URI"] = "bolt://localhost:7687"
os.environ["NEO4J_USERNAME"] = "neo4j"
os.environ["NEO4J_PASSWORD"] = "<YOUR_NEO4J_DB_PASSWORD"

# %%
from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    ConfigurableField, RunnableParallel, RunnablePassthrough
)
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import Tuple, List, Optional
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
import os
from langchain_community.graphs import Neo4jGraph
from langchain.document_loaders import WikipediaLoader
from langchain.text_splitter import TokenTextSplitter
from langchain_openai import ChatOpenAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
from neo4j import GraphDatabase
from yfiles_jupyter_graphs import GraphWidget
from langchain_community.vectorstores import Neo4jVector
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
from importlib import reload
import utils

import warnings
warnings.filterwarnings('ignore')
#reload(utils)

# %% [markdown]
# ### Connect to the Neo4j database
# Connect to the graph database using the [LangChain Neo4jGraph connector](https://api.python.langchain.com/en/latest/graphs/langchain_community.graphs.neo4j_graph.Neo4jGraph.html).

# %%
# Create a Neo4jGraph object to interact with the graph database
graph = Neo4jGraph(database="neo4j")

# %% [markdown]
# ### Data Ingestion
# Load 1MDB scandal Wikipedia page using the [LangChain Wikipedia loader](https://api.python.langchain.com/en/latest/document_loaders/langchain_community.document_loaders.wikipedia.WikipediaLoader.html)

# %%
# Read the wikipedia article using WikipediaLoader 
raw_documents = WikipediaLoader(query="1Malaysia Development Berhad scandal", load_max_docs=1, doc_content_chars_max=47568).load()
# Define chunking strategy
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
# Split the documents into chunks based on the chunking strategy
documents = text_splitter.split_documents(raw_documents)

# %%
raw_documents
# Out:
# [Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...

# %%
documents
# Out:
# [Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
# ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...
#  Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of ...

# %% [markdown]
# ### Construct a graph based on the retrieved documents
# The [LLMGraphTransformer](https://python.langchain.com/v0.2/api_reference/experimental/graph_transformers/langchain_experimental.graph_transformers.llm.LLMGraphTransformer.html) returns graph documents, which can be imported to the Neo4j graph database via the [add_graph_documents](https://api.python.langchain.com/en/latest/graphs/langchain_community.graphs.neo4j_graph.Neo4jGraph.html#langchain_community.graphs.neo4j_graph.Neo4jGraph.add_graph_documents) method. The `baseEntityLabel` parameter assigns an additional __Entity__ label to each node, enhancing indexing and query performance. The `include_source` parameter links nodes to their originating documents, facilitating data traceability and context understanding. Define the LLM for knowledge graph generation chain usage.

# %%
# Create the LLM using gpt-4o
llm=ChatOpenAI(temperature=0, model_name="gpt-4o")

# Create the LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm=llm)

# Convert the documents to graph documents
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# Add the documents to the graph
graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='1Mdb', type='Organization', properties={}), Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Jho Low', type='Person', properties={}), Node(id='United States Department Of Justice', type='Organization', properties={}), Node(id='The Edge', type='Organization', properties={}), Node(id='Sarawak Report', type='Organization', properties={}), Node(id='The Wall Street Journal', type='Organization', properties={}), Node(id='Equanimity', type='Object', properties={}), Node(id='Red Granite Pictures', type='Organization', properties={}), Node(id='The Wolf Of Wall Street', type='Creative_work', properties={}), Node(id='Rosmah Mansor', type='Person', properties={}), Node(id='Riza Aziz', type='Person', properties={}), Node(id='Muhyiddin Yassin', type='Person', properties={}), Node(id='Abdul Gani Patail', type='Person', properties={}), Node(id='Mahathir Mohamad', type='Person', properties={}), Node(id="Malaysian Citizens' Declaration", type='Document', properties={})], relationships=[Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='United States Department Of Justice', type='Organization', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='The Edge', type='Organization', properties={}), type='REPORTED_BY', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Sarawak Report', type='Organization', properties={}), type='REPORTED_BY', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='The Wall Street Journal', type='Organization', properties={}), type='REPORTED_BY', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Equanimity', type='Object', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Red Granite Pictures', type='Organization', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='The Wolf Of Wall Street', type='Creative_work', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Rosmah Mansor', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Riza Aziz', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Muhyiddin Yassin', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}), target=Node(id='Abdul Gani Patail', type='Person', properties={}), type='INVOLVES', properties={}), Relationship(source=Node(id='1Malaysia Development Berhad Scandal', type='Event', properties={}),  ...
#  GraphDocument(nodes=[Node(id='Najib Razak', type='Person', properties={}), Node(id='Malaysian Conference Of Rulers', type='Organization', properties={}), Node(id='Malaysia', type='Country', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Goldman Sachs', type='Organization', properties={}), Node(id='U.S. Department Of Justice', type='Organization', properties={}), Node(id='Pras', type='Person', properties={}), Node(id='Tim Leissner', type='Person', properties={}), Node(id='Elliott Broidy', type='Person', properties={}), Node(id='Mahathir Mohamad', type='Person', properties={}), Node(id='Malaysian Immigration Department', type='Organization', properties={}), Node(id='Jho Low', type='Person', properties={}), Node(id='Src International', type='Organization', properties={}), Node(id='United States', type='Country', properties={}), Node(id='Singapore', type='Country', properties={})], relationships=[Relationship(source=Node(id='Malaysian Conference Of Rulers', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='CALL_FOR_RESIGNATION', properties={}), Relationship(source=Node(id='Malaysian Conference Of Rulers', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='CALL_FOR_INVESTIGATION', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Goldman Sachs', type='Organization', properties={}), type='DEBT_INVOLVEMENT', properties={}), Relationship(source=Node(id='Goldman Sachs', type='Organization', properties={}), target=Node(id='U.S. Department Of Justice', type='Organization', properties={}), type='SETTLEMENT', properties={}), Relationship(source=Node(id='U.S. Department Of Justice', type='Organization', properties={}), target=Node(id='Goldman Sachs', type='Organization', properties={}), type='CHARGED', properties={}), Relationship(source=Node(id='U.S. Department Of Justice', type='Organization', properties={}), target=Node(id='Pras', type='Person', properties={}), type='CHARGED', properties={}), Relationship(source=Node(id='U.S. Department Of Justice', type='Organization', properties={}), target=Node(id='Tim Leissner', type='Person', properties={}), type='CHARGED', properties={}), Relationship(source=Node(id='U.S. Department Of Justice', type='Organization', properties={}), target=Node(id='Elliott Broidy', type='Person', properties={}), type='CHARGED', properties={}), Relationship(source=Node(id='Mahathir Mohamad', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='REOPEN_INVESTIGATION', properties={}), Relationship(source=Node(id='Malaysian Immigration Department', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='TRAVEL_BAN', properties={}), Relationship(source=Node(id='Malaysian Immigration Department', type='Organization', properties={}), target=Node(id='11 Others', type='Person', properties={}), type='TRAVEL_BAN', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Src International', type='Organization', properties={}), type='GUILTY', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='CHARGED', properties={}), Relationship(source=Node(id='United States', type='Country', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='FUNDS_RECOVERY', properties={}), Relationship(source=Node(id='Singapore', type='Country', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='FUNDS_RECOVERY', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Malaysia', type='Country', properties={}), type='PRIME_MINISTER', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', ...
#  GraphDocument(nodes=[Node(id='Najib Razak', type='Person', properties={}), Node(id='1Malaysia Development Berhad', type='Organization', properties={}), Node(id='Rosmah Mansor', type='Person', properties={}), Node(id='Riza Aziz', type='Person', properties={}), Node(id='Jho Low', type='Person', properties={}), Node(id='Tim Leissner', type='Person', properties={}), Node(id='Goldman Sachs', type='Organization', properties={}), Node(id='Roger Ng', type='Person', properties={}), Node(id='Petrosaudi', type='Organization', properties={}), Node(id='Turki Bin Abdullah Al Saud', type='Person', properties={}), Node(id='Tarek Obaid', type='Person', properties={})], relationships=[Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='1Malaysia Development Berhad', type='Organization', properties={}), type='ESTABLISHED', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Rosmah Mansor', type='Person', properties={}), type='SPOUSE', properties={}), Relationship(source=Node(id='Rosmah Mansor', type='Person', properties={}), target=Node(id='Riza Aziz', type='Person', properties={}), type='PARENT', properties={}), Relationship(source=Node(id='Jho Low', type='Person', properties={}), target=Node(id='1Malaysia Development Berhad', type='Organization', properties={}), type='SUPPORTED', properties={}), Relationship(source=Node(id='Tim Leissner', type='Person', properties={}), target=Node(id='Goldman Sachs', type='Organization', properties={}), type='CHAIRMAN', properties={}), Relationship(source=Node(id='Roger Ng', type='Person', properties={}), target=Node(id='Goldman Sachs', type='Organization', properties={}), type='HEAD', properties={}), Relationship(source=Node(id='Roger Ng', type='Person', properties={}), target=Node(id='Tim Leissner', type='Person', properties={}), type='INTRODUCED', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Petrosaudi', type='Organization', properties={}), type='JOINT_VENTURE', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='MET', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Turki Bin Abdullah Al Saud', type='Person', properties={}), type='MET', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Tarek Obaid', type='Person', properties={}), type='MET', properties={}), Relationship(source=Node(id='Goldman Sachs', type='Organization', properties={}), target=Node(id='1Malaysia Development Berhad', type='Organization', properties={}), type='RAISED_FUNDS', properties={}), Relationship(source=Node(id='Goldman Sachs', type='Organization', properties={}), target=Node(id='Roger Ng', type='Person', properties={}), type='CENTRAL_ORCHESTRATOR', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million ...
#  GraphDocument(nodes=[Node(id='1Mdb', type='Organization', properties={}), Node(id='Low', type='Person', properties={}), Node(id='Doj', type='Organization', properties={}), Node(id='Petrosaudi', type='Organization', properties={}), Node(id='Red Granite Pictures', type='Organization', properties={}), Node(id='Riza Aziz', type='Person', properties={}), Node(id='Joey Mcfarland', type='Person', properties={}), Node(id='The Wolf Of Wall Street', type='Creative_work', properties={}), Node(id="Daddy'S Home", type='Creative_work', properties={}), Node(id='Dumb And Dumber To', type='Creative_work', properties={}), Node(id='Tony Pua', type='Person', properties={}), Node(id='Najib', type='Person', properties={}), Node(id='Kpmg', type='Organization', properties={}), Node(id='Deloitte', type='Organization', properties={}), Node(id='Ernst & Young', type='Organization', properties={}), Node(id='Companies Commission Of Malaysia', type='Organization', properties={})], relationships=[Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Low', type='Person', properties={}), type='FUNDED_LIFESTYLE', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Red Granite Pictures', type='Organization', properties={}), type='FUNDED', properties={}), Relationship(source=Node(id='Red Granite Pictures', type='Organization', properties={}), target=Node(id='The Wolf Of Wall Street', type='Creative_work', properties={}), type='PRODUCED', properties={}), Relationship(source=Node(id='Red Granite Pictures', type='Organization', properties={}), target=Node(id="Daddy'S Home", type='Creative_work', properties={}), type='PRODUCED', properties={}), Relationship(source=Node(id='Red Granite Pictures', type='Organization', properties={}), target=Node(id='Dumb And Dumber To', type='Creative_work', properties={}), type='PRODUCED', properties={}), Relationship(source=Node(id='Doj', type='Organization', properties={}), target=Node(id='The Wolf Of Wall Street', type='Creative_work', properties={}), type='SEIZED_ROYALTIES', properties={}), Relationship(source=Node(id='Doj', type='Organization', properties={}), target=Node(id="Daddy'S Home", type='Creative_work', properties={}), type='SEIZED_ROYALTIES', properties={}), Relationship(source=Node(id='Doj', type='Organization', properties={}), target=Node(id='Dumb And Dumber To', type='Creative_work', properties={}), type='SEIZED_ROYALTIES', properties={}), Relationship(source=Node(id='Riza Aziz', type='Person', properties={}), target=Node(id='Red Granite Pictures', type='Organization', properties={}), type='CO-FOUNDED', properties={}), Relationship(source=Node(id='Joey Mcfarland', type='Person', properties={}), target=Node(id='Red Granite Pictures', type='Organization', properties={}), type='CO-FOUNDED', properties={}), Relationship(source=Node(id='Tony Pua', type='Person', properties={}), target=Node(id='Najib', type='Person', properties={}), type='QUESTIONED', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Kpmg', type='Organization', properties={}), type='AUDITED_BY', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Deloitte', type='Organization', properties={}), type='VALUED_BY', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Ernst & Young', type='Organization', properties={}), type='ADVISED_BY', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Companies Commission Of Malaysia', type='Organization', properties={}), type='REPORTED_TO', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sov ...
#  GraphDocument(nodes=[Node(id='Sungai_Besi_Airport_Land', type='Location', properties={}), Node(id='June_2011', type='Date', properties={}), Node(id='Bandar_Malaysia', type='Project', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Rm_3.5_Billion', type='Amount', properties={}), Node(id='April_2013', type='Date', properties={}), Node(id='Perbadanan_Perwira_Harta_Malaysia', type='Organization', properties={}), Node(id='Lembaga_Tabung_Angkatan_Tentera', type='Organization', properties={}), Node(id='Pangkalan_Udara_Kuala_Lumpur', type='Location', properties={}), Node(id='31_December_2015', type='Date', properties={}), Node(id='Iskandar_Waterfront_Holdings', type='Organization', properties={}), Node(id='China_Railway_Engineering_Corporation', type='Organization', properties={}), Node(id='Abdul_Samad_Alias', type='Person', properties={}), Node(id='7_September_2015', type='Date', properties={}), Node(id='Arul_Kanda', type='Person', properties={}), Node(id='Deloitte_Malaysia', type='Organization', properties={}), Node(id='July_2016', type='Date', properties={}), Node(id='28_March_2014', type='Date', properties={}), Node(id='5_November_2014', type='Date', properties={}), Node(id='Prime_Minister', type='Person', properties={}), Node(id='Auditor_General_Of_Malaysia', type='Organization', properties={}), Node(id='Public_Accounts_Committee', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Sungai_Besi_Airport_Land', type='Location', properties={}), target=Node(id='June_2011', type='Date', properties={}), type='TRANSFER_DATE', properties={}), Relationship(source=Node(id='Sungai_Besi_Airport_Land', type='Location', properties={}), target=Node(id='Bandar_Malaysia', type='Project', properties={}), type='DEVELOPMENT_SITE', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Rm_3.5_Billion', type='Amount', properties={}), type='RAISED_FUNDS', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='April_2013', type='Date', properties={}), type='CONTRACT_AWARD_DATE', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Perbadanan_Perwira_Harta_Malaysia', type='Organization', properties={}), type='CONTRACT_AWARDEE', properties={}), Relationship(source=Node(id='Perbadanan_Perwira_Harta_Malaysia', type='Organization', properties={}), target=Node(id='Lembaga_Tabung_Angkatan_Tentera', type='Organization', properties={}), type='SUBSIDIARY_OF', properties={}), Relationship(source=Node(id='Pangkalan_Udara_Kuala_Lumpur', type='Location', properties={}), target=Node(id='Sungai_Besi_Airport_Land', type='Location', properties={}), type='RELOCATION_SITE', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='31_December_2015', type='Date', properties={}), type='AGREEMENT_DATE', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Iskandar_Waterfront_Holdings', type='Organization', properties={}), type='CONSORTIUM_MEMBER', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='China_Railway_Engineering_Corporation', type='Organization', properties={}), type='CONSORTIUM_MEMBER', properties={}), Relationship(source=Node(id='Abdul_Samad_Alias', type='Person', properties={}), target=Node(id='7_September_2015', type='Date', properties={}), type='RESIGNATION_DATE', properties={}), Relationship(source=Node(id='Abdul_Samad_Alias', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='BOARD_MEMBER', properties={}), Relationship(source=Node(id='Arul_Kanda', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='PRESIDENT', properties={}), Relationship(source=Node(id='Deloitte_Malaysia', type='Organization', properties={}), ...
#  GraphDocument(nodes=[Node(id='Audit_Report', type='Document', properties={}), Node(id='Public_Accounts_Committee', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Najib', type='Person', properties={}), Node(id='New_Government', type='Organization', properties={}), Node(id='Pakatan_Harapan', type='Organization', properties={}), Node(id='Lim_Guan_Eng', type='Person', properties={}), Node(id='Pricewaterhousecoopers', type='Organization', properties={}), Node(id='Debts_2015', type='Financial_issue', properties={}), Node(id='Malaysian_Cabinet', type='Organization', properties={}), Node(id='Macc', type='Organization', properties={}), Node(id='Umno', type='Organization', properties={}), Node(id='Wan_Adnan_Wan_Mamat', type='Person', properties={}), Node(id='Saudi_Arabia', type='Country', properties={}), Node(id='Isis', type='Organization', properties={}), Node(id='Muslim_Community_Philippines', type='Community', properties={}), Node(id='Muslim_Community_Thailand', type='Community', properties={}), Node(id='Adel_Al-Jubeir', type='Person', properties={}), Node(id='Mohamad_Apandi_Ali', type='Person', properties={}), Node(id='Turki_Bin_Abdullah_Al_Saud', type='Person', properties={}), Node(id='King_Abdullah', type='Person', properties={}), Node(id='Abc_News', type='Organization', properties={}), Node(id='Wsj', type='Organization', properties={}), Node(id='Ken_Brown', type='Person', properties={}), Node(id='Bank_Negara', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Audit_Report', type='Document', properties={}), target=Node(id='Public_Accounts_Committee', type='Organization', properties={}), type='CLASSIFIED_AS_SECRET', properties={}), Relationship(source=Node(id='Public_Accounts_Committee', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='INVESTIGATE', properties={}), Relationship(source=Node(id='Najib', type='Person', properties={}), target=Node(id='Audit_Report', type='Document', properties={}), type='OUSTER_RELATED', properties={}), Relationship(source=Node(id='New_Government', type='Organization', properties={}), target=Node(id='Audit_Report', type='Document', properties={}), type='DECLASSIFIED', properties={}), Relationship(source=Node(id='Pakatan_Harapan', type='Organization', properties={}), target=Node(id='New_Government', type='Organization', properties={}), type='FORMED', properties={}), Relationship(source=Node(id='Lim_Guan_Eng', type='Person', properties={}), target=Node(id='Pricewaterhousecoopers', type='Organization', properties={}), type='APPOINTED', properties={}), Relationship(source=Node(id='Pricewaterhousecoopers', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='AUDIT', properties={}), Relationship(source=Node(id='Debts_2015', type='Financial_issue', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='ACCUMULATED', properties={}), Relationship(source=Node(id='Malaysian_Cabinet', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='REJECTED_CASH_INJECTION', properties={}), Relationship(source=Node(id='Macc', type='Organization', properties={}), target=Node(id='Najib', type='Person', properties={}), type='STATEMENT_ABOUT_DONATION', properties={}), Relationship(source=Node(id='Wan_Adnan_Wan_Mamat', type='Person', properties={}), target=Node(id='Najib', type='Person', properties={}), type='CLAIMED_DONATION_FROM_SAUDI_ARABIA', properties={}), Relationship(source=Node(id='Saudi_Arabia', type='Country', properties={}), target=Node(id='Isis', type='Organization', properties={}), type='THANKS_FOR_FIGHTING', properties={}), Relationship(source=Node(id='Muslim_Community_Philippines', type='Community', properties={}), target=Node(id='Najib', type='Person', properties={}), type='RECEIVED_SIMILAR_DONATIONS', properties={}), Relationship(source=Node(id='Muslim_C ...
#  GraphDocument(nodes=[Node(id='1Mdb', type='Organization', properties={}), Node(id='Bank Negara', type='Organization', properties={}), Node(id='Attorney General', type='Person', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Umno', type='Organization', properties={}), Node(id='Abdul Rauf Yusof', type='Person', properties={}), Node(id='Anina Saadudin', type='Person', properties={}), Node(id='Abdul Rashed Jamaludin', type='Person', properties={}), Node(id='Khairuddin Abu Hassan', type='Person', properties={}), Node(id='Matthias Chang', type='Person', properties={}), Node(id='Swiss Attorney General', type='Person', properties={}), Node(id='Jho Low', type='Person', properties={}), Node(id='Alliance Assets International', type='Organization', properties={}), Node(id='Cityfield Enterprises', type='Organization', properties={}), Node(id='Bartingale International', type='Organization', properties={}), Node(id='Wonder Quest Investment', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Bank Negara', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='REVOKED_PERMISSIONS', properties={}), Relationship(source=Node(id='Bank Negara', type='Organization', properties={}), target=Node(id='Attorney General', type='Person', properties={}), type='CALLED_FOR_PROSECUTION', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='MEMBER', properties={}), Relationship(source=Node(id='Abdul Rauf Yusof', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='EXECUTIVE_SECRETARY', properties={}), Relationship(source=Node(id='Anina Saadudin', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='FILED_LAWSUIT', properties={}), Relationship(source=Node(id='Abdul Rashed Jamaludin', type='Person', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='FILED_POLICE_REPORT', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='FILED_POLICE_REPORT', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='FILED_POLICE_REPORT', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Swiss Attorney General', type='Person', properties={}), type='SUBMITTED_EVIDENCE', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Alliance Assets International', type='Organization', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Cityfield Enterprises', type='Organization', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Bartingale International', type='Organization', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Wonder Quest Investment', type='Organization', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Matthias Chang', type='Person', properties={}), target=Node(id='Swiss Attorney General', type='Person', properties={}), type='SUBMITTED_EVIDENCE', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad ...
#  GraphDocument(nodes=[Node(id='Ingale International', type='Organization', properties={}), Node(id='Wonder Quest Investment', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Khairuddin', type='Person', properties={}), Node(id='Matthias', type='Person', properties={}), Node(id='Security Offenses Act (Sosma)', type='Legal_act', properties={}), Node(id="People'S Justice Party (Pkr)", type='Organization', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Tengku Adnan Tengku Mansor', type='Person', properties={}), Node(id='Election Commission', type='Organization', properties={}), Node(id='Malaysian High Court', type='Organization', properties={}), Node(id='Mahathir', type='Person', properties={}), Node(id='Muhyiddin Yassin', type='Person', properties={}), Node(id='Ahmad Zahid Hamidi', type='Person', properties={}), Node(id='Shafie Apdal', type='Person', properties={}), Node(id='Umno', type='Organization', properties={}), Node(id='Abdul Gani Patail', type='Person', properties={}), Node(id='Mohamed Apandi Ali', type='Person', properties={}), Node(id='Public Action Committee', type='Organization', properties={}), Node(id='Nur Jazlan Mohamed', type='Person', properties={}), Node(id='Reezal Merican Naina Merican', type='Person', properties={}), Node(id='Wilfred Madius Tangau', type='Person', properties={}), Node(id='Mas Ermieyati Samsudin', type='Person', properties={}), Node(id='The Edge Malaysia', type='Organization', properties={}), Node(id='The Edge Financial Daily', type='Organization', properties={}), Node(id='Malaysian Home Ministry', type='Organization', properties={}), Node(id='Sarawak Report', type='Website', properties={}), Node(id='Malaysian Communications And Multimedia Commission', type='Organization', properties={}), Node(id='Clare Rewcastle Brown', type='Person', properties={})], relationships=[Relationship(source=Node(id='Ingale International', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='DEALINGS_WITH', properties={}), Relationship(source=Node(id='Wonder Quest Investment', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='DEALINGS_WITH', properties={}), Relationship(source=Node(id='Khairuddin', type='Person', properties={}), target=Node(id='Malaysia', type='Location', properties={}), type='BARRED_FROM_LEAVING', properties={}), Relationship(source=Node(id='Matthias', type='Person', properties={}), target=Node(id='Malaysia', type='Location', properties={}), type='BARRED_FROM_LEAVING', properties={}), Relationship(source=Node(id='Khairuddin', type='Person', properties={}), target=Node(id='Security Offenses Act (Sosma)', type='Legal_act', properties={}), type='CHARGED_UNDER', properties={}), Relationship(source=Node(id='Matthias', type='Person', properties={}), target=Node(id='Security Offenses Act (Sosma)', type='Legal_act', properties={}), type='CHARGED_UNDER', properties={}), Relationship(source=Node(id="People'S Justice Party (Pkr)", type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='FILED_LAWSUIT_AGAINST', properties={}), Relationship(source=Node(id="People'S Justice Party (Pkr)", type='Organization', properties={}), target=Node(id='Tengku Adnan Tengku Mansor', type='Person', properties={}), type='FILED_LAWSUIT_AGAINST', properties={}), Relationship(source=Node(id="People'S Justice Party (Pkr)", type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='FILED_LAWSUIT_AGAINST', properties={}), Relationship(source=Node(id="People'S Justice Party (Pkr)", type='Organization', properties={}), target=Node(id='Election Commission', type='Organization', properties={}), type='FILED_LAWSUIT_AGAINST', properties={}), Relationship(source=Node(id='Malaysian High Court', type='Organization', properties={}), target=Node(id="People'S Justice Party (P ...
#  GraphDocument(nodes=[Node(id='Najib', type='Person', properties={}), Node(id='Khairuddin Abu Hassan', type='Person', properties={}), Node(id='Umno', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Fbi', type='Organization', properties={}), Node(id='Mukhriz Mahathir', type='Person', properties={}), Node(id='Mahathir Mohamad', type='Person', properties={}), Node(id='Rafizi Ramli', type='Person', properties={}), Node(id='Home Ministry', type='Organization', properties={}), Node(id='Interpol', type='Organization', properties={}), Node(id='Jho Low', type='Person', properties={}), Node(id='Casey Tang Keng Chee', type='Person', properties={}), Node(id='Jasmine Loo Ai Swan', type='Person', properties={}), Node(id='Nik Faisal Ariff Kamil', type='Person', properties={}), Node(id='Yusof Annuar Yaacob', type='Person', properties={}), Node(id='Deutsche Bank', type='Organization', properties={}), Node(id='Malaysian Communications And Multimedia Commission', type='Organization', properties={}), Node(id='Medium.Com', type='Website', properties={}), Node(id='Sarawak Report', type='Organization', properties={}), Node(id='Asia Sentinel', type='Website', properties={}), Node(id='Malaysian Insider', type='Website', properties={}), Node(id='Macc', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='MEMBER_OF', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='REPORTED', properties={}), Relationship(source=Node(id='Khairuddin Abu Hassan', type='Person', properties={}), target=Node(id='Fbi', type='Organization', properties={}), type='INTENDED_TO_MEET', properties={}), Relationship(source=Node(id='Mukhriz Mahathir', type='Person', properties={}), target=Node(id='Najib', type='Person', properties={}), type='CRITICIZED', properties={}), Relationship(source=Node(id='Mukhriz Mahathir', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='EXPELLED_FROM', properties={}), Relationship(source=Node(id='Mahathir Mohamad', type='Person', properties={}), target=Node(id='Najib', type='Person', properties={}), type='WITHDREW_SUPPORT', properties={}), Relationship(source=Node(id='Mahathir Mohamad', type='Person', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='QUIT', properties={}), Relationship(source=Node(id='Rafizi Ramli', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='LEAKED_INFORMATION', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Interpol', type='Organization', properties={}), type='COLLABORATED_WITH', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='SEARCHED_FOR', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Casey Tang Keng Chee', type='Person', properties={}), type='SEARCHED_FOR', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Jasmine Loo Ai Swan', type='Person', properties={}), type='SEARCHED_FOR', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Nik Faisal Ariff Kamil', type='Person', properties={}), type='SEARCHED_FOR', properties={}), Relationship(source=Node(id='Home Ministry', type='Organization', properties={}), target=Node(id='Yusof Annuar Yaacob', type='Person', properties={}), type='SEARCHED_FOR', properties={}), Relationship(source=Node(id='Yusof Annuar Yaacob', type='Person', properties={}), target=Node(id='Deutsche Bank', type='Org ...
#  GraphDocument(nodes=[Node(id='Malaysian Public Accounts Committee', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Aabar Investments Pjs', type='Organization', properties={}), Node(id='Ipic', type='Organization', properties={}), Node(id='International Petroleum Investment Company', type='Organization', properties={}), Node(id='Barisan Nasional', type='Organization', properties={}), Node(id='Pakatan Harapan', type='Organization', properties={}), Node(id='Mahathir Mohamad', type='Person', properties={}), Node(id='Tan Sri Abdul Gani Patail', type='Person', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Rosmah Mansor', type='Person', properties={}), Node(id='Macc', type='Organization', properties={}), Node(id='Jho Low', type='Person', properties={})], relationships=[Relationship(source=Node(id='Malaysian Public Accounts Committee', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='INQUIRY', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='CHAIRMAN', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Aabar Investments Pjs', type='Organization', properties={}), type='PAYMENT', properties={}), Relationship(source=Node(id='Ipic', type='Organization', properties={}), target=Node(id='Aabar Investments Pjs', type='Organization', properties={}), type='NO_LINK', properties={}), Relationship(source=Node(id='International Petroleum Investment Company', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='DEBT_TERMINATION', properties={}), Relationship(source=Node(id='Barisan Nasional', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='LED_BY', properties={}), Relationship(source=Node(id='Pakatan Harapan', type='Organization', properties={}), target=Node(id='Mahathir Mohamad', type='Person', properties={}), type='LED_BY', properties={}), Relationship(source=Node(id='Pakatan Harapan', type='Organization', properties={}), target=Node(id='Tan Sri Abdul Gani Patail', type='Person', properties={}), type='TASK_FORCE_HEAD', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Rosmah Mansor', type='Person', properties={}), type='SPOUSE', properties={}), Relationship(source=Node(id='Macc', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='ARRESTED', properties={}), Relationship(source=Node(id='Najib Razak', type='Person', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='ARREST_WARRANT', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-ru ...
#  GraphDocument(nodes=[Node(id='Jho Low', type='Person', properties={}), Node(id='Nik Faisal Ariff Kamil', type='Person', properties={}), Node(id='Src International', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Arul Kanda', type='Person', properties={}), Node(id='Umno', type='Organization', properties={}), Node(id='Macc', type='Organization', properties={}), Node(id='Larry Low', type='Person', properties={}), Node(id='Equanimity', type='Object', properties={}), Node(id='Genting Group', type='Organization', properties={}), Node(id='Goldman Sachs', type='Organization', properties={}), Node(id='Tim Leissner', type='Person', properties={}), Node(id='Roger Ng Chong Hwa', type='Person', properties={}), Node(id='Jasmine Loo', type='Person', properties={}), Node(id='Mohammed Bin Zayed', type='Person', properties={}), Node(id='Najib Tun Razak', type='Person', properties={}), Node(id='Ipic', type='Organization', properties={}), Node(id="Najib'S Stepson", type='Person', properties={}), Node(id="Najib'S Wife Rosmah Mansor", type='Person', properties={})], relationships=[Relationship(source=Node(id='Government', type='Organization', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='ISSUED_ARREST_WARRANT', properties={}), Relationship(source=Node(id='Government', type='Organization', properties={}), target=Node(id='Nik Faisal Ariff Kamil', type='Person', properties={}), type='ISSUED_ARREST_WARRANT', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Arul Kanda', type='Person', properties={}), type='SACKED', properties={}), Relationship(source=Node(id='Macc', type='Organization', properties={}), target=Node(id='Umno', type='Organization', properties={}), type='FROZE_BANK_ACCOUNTS', properties={}), Relationship(source=Node(id='Malaysian Police', type='Organization', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Malaysian Police', type='Organization', properties={}), target=Node(id='Larry Low', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Jho Low', type='Person', properties={}), target=Node(id='Equanimity', type='Object', properties={}), type='PURCHASED_WITH_STOLEN_FUNDS', properties={}), Relationship(source=Node(id='Genting Group', type='Organization', properties={}), target=Node(id='Equanimity', type='Object', properties={}), type='PURCHASED', properties={}), Relationship(source=Node(id='Attorney-General Chambers Of Malaysia', type='Organization', properties={}), target=Node(id='Goldman Sachs', type='Organization', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Attorney-General Chambers Of Malaysia', type='Organization', properties={}), target=Node(id='Tim Leissner', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Attorney-General Chambers Of Malaysia', type='Organization', properties={}), target=Node(id='Roger Ng Chong Hwa', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Attorney-General Chambers Of Malaysia', type='Organization', properties={}), target=Node(id='Jasmine Loo', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Attorney-General Chambers Of Malaysia', type='Organization', properties={}), target=Node(id='Jho Low', type='Person', properties={}), type='FILED_CRIMINAL_CHARGES', properties={}), Relationship(source=Node(id='Najib Tun Razak', type='Person', properties={}), target=Node(id='Mohammed Bin Zayed', type='Person', properties={}), type='ASKED_TO_FABRICATE_LOAN_AGREEMENT', properties={}), Relationship(source=Node(id='Najib Tun Razak', type='Person', properties={}), target=Node(id="Najib'S Stepson", type='Person',  ...
# ...
#  GraphDocument(nodes=[Node(id='Clare Rewcastle-Brown', type='Person', properties={}), Node(id='Sarawak Report', type='Organization', properties={}), Node(id='Xavier Justo', type='Person', properties={}), Node(id='Petrosaudi International', type='Organization', properties={}), Node(id='Team Jorge', type='Organization', properties={}), Node(id='Low Taek Jho', type='Person', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Good Star Ltd', type='Organization', properties={}), Node(id='Suaad A. Al-Attas', type='Person', properties={}), Node(id='Mohammed Badawy Al Husseiny', type='Person', properties={}), Node(id='Tom Bock', type='Person', properties={}), Node(id='The Edge', type='Organization', properties={}), Node(id='Malaysian Government', type='Organization', properties={}), Node(id='Wall Street Journal', type='Organization', properties={}), Node(id='Genting Group', type='Organization', properties={})], relationships=[Relationship(source=Node(id='Clare Rewcastle-Brown', type='Person', properties={}), target=Node(id='Sarawak Report', type='Organization', properties={}), type='WRITES', properties={}), Relationship(source=Node(id='Xavier Justo', type='Person', properties={}), target=Node(id='Petrosaudi International', type='Organization', properties={}), type='FORMER_EMPLOYEE', properties={}), Relationship(source=Node(id='Team Jorge', type='Organization', properties={}), target=Node(id='Xavier Justo', type='Person', properties={}), type='TARGETED', properties={}), Relationship(source=Node(id='Low Taek Jho', type='Person', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='HAS_TIES', properties={}), Relationship(source=Node(id='Low Taek Jho', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='CONSULTED', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Petrosaudi International', type='Organization', properties={}), type='JOINT_VENTURE', properties={}), Relationship(source=Node(id='Low Taek Jho', type='Person', properties={}), target=Node(id='Good Star Ltd', type='Organization', properties={}), type='SIPHONED_FUNDS', properties={}), Relationship(source=Node(id='Suaad A. Al-Attas', type='Person', properties={}), target=Node(id='Mohammed Badawy Al Husseiny', type='Person', properties={}), type='FORMER_WIFE', properties={}), Relationship(source=Node(id='Suaad A. Al-Attas', type='Person', properties={}), target=Node(id='Tom Bock', type='Person', properties={}), type='SHAREHOLDER', properties={}), Relationship(source=Node(id='The Edge', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='INVESTIGATED', properties={}), Relationship(source=Node(id='Malaysian Government', type='Organization', properties={}), target=Node(id='The Edge', type='Organization', properties={}), type='SUSPENDED_LICENSE', properties={}), Relationship(source=Node(id='Wall Street Journal', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='REPORTED_ON', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Genting Group', type='Organization', properties={}), type='PURCHASED_ASSETS', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number ...
#  GraphDocument(nodes=[Node(id='1Mdb', type='Organization', properties={}), Node(id='The Wall Street Journal', type='Organization', properties={}), Node(id='Najib Razak', type='Person', properties={}), Node(id='Ambank', type='Organization', properties={}), Node(id='Affin Bank', type='Organization', properties={}), Node(id='Malaysian Anti-Corruption Commission', type='Organization', properties={}), Node(id='Singapore Police', type='Organization', properties={}), Node(id='Falcon Bank', type='Organization', properties={}), Node(id='International Petroleum Investment Company', type='Organization', properties={}), Node(id='British Virgin Islands-Registered Company', type='Organization', properties={})], relationships=[Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='TRANSFERRED_FUNDS_TO', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Ambank', type='Organization', properties={}), type='TRANSFERRED_FUNDS_TO', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Affin Bank', type='Organization', properties={}), type='TRANSFERRED_FUNDS_TO', properties={}), Relationship(source=Node(id='The Wall Street Journal', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='ALLEGED_FUNDS_TRANSFER', properties={}), Relationship(source=Node(id='Malaysian Anti-Corruption Commission', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='CLEARED', properties={}), Relationship(source=Node(id='Singapore Police', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='INVESTIGATED', properties={}), Relationship(source=Node(id='Singapore Police', type='Organization', properties={}), target=Node(id='Najib Razak', type='Person', properties={}), type='INVESTIGATED', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Falcon Bank', type='Organization', properties={}), type='TRANSFERRED_FUNDS_THROUGH', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='British Virgin Islands-Registered Company', type='Organization', properties={}), type='TRANSFERRED_FUNDS_TO', properties={}), Relationship(source=Node(id='British Virgin Islands-Registered Company', type='Organization', properties={}), target=Node(id='International Petroleum Investment Company', type='Organization', properties={}), type='CONTROLLED_BY', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice fo ...
#  GraphDocument(nodes=[Node(id='Ipic', type='Organization', properties={}), Node(id='1Mdb', type='Organization', properties={}), Node(id='Malaysian Ministry Of Finance', type='Organization', properties={}), Node(id='Wsj', type='Organization', properties={}), Node(id='Dusable Capital Management Llc', type='Organization', properties={}), Node(id='Yurus Pe Fund', type='Organization', properties={}), Node(id='Najib', type='Person', properties={})], relationships=[Relationship(source=Node(id='Ipic', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='ASSUMED_OBLIGATION_FOR_BOND', properties={}), Relationship(source=Node(id='Ipic', type='Organization', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='CASH_PAYMENT', properties={}), Relationship(source=Node(id='Ipic', type='Organization', properties={}), target=Node(id='Malaysian Ministry Of Finance', type='Organization', properties={}), type='COMMITMENT_TO_WORK_WITH', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Dusable Capital Management Llc', type='Organization', properties={}), type='JOINT_VENTURE_AGREEMENT', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Yurus Pe Fund', type='Organization', properties={}), type='CREATED_FUND', properties={}), Relationship(source=Node(id='1Mdb', type='Organization', properties={}), target=Node(id='Dusable Capital Management Llc', type='Organization', properties={}), type='BOUGHT_OUT_STAKE', properties={}), Relationship(source=Node(id='Najib', type='Person', properties={}), target=Node(id='1Mdb', type='Organization', properties={}), type='FUNDS_DIVERTED_FROM', properties={})], source=Document(metadata={'title': '1Malaysia Development Berhad scandal', 'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yas ...

# %% [markdown]
# ### Inspect the generated graph with yfiles visualization.

# %%
# directly show the graph resulting from the given Cypher query
default_cypher = '''
MATCH (s)-[r]->(t)
WHERE NOT type(r) = 'MENTIONS'
RETURN s, r, t
LIMIT 50
'''

def showGraph(cypher: str = default_cypher):
    # create a neo4j session to run queries
    driver = utils.neo4j_driver
    # create a graph widget to display the graph
    session = driver.session(database="neo4j")
    widget = GraphWidget(graph = session.run(cypher).graph())
    widget.node_label_mapping = 'id'
    return widget

showGraph()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# Let's take a deeper look into the graphs in Neo4j

# %%
# person with most relationships
'''
MATCH (n:Person)-[r]-()
RETURN n, COUNT(r) AS total_count
ORDER BY total_count DESC
LIMIT 1
'''

# all relationships of that person
'''
MATCH (n:Person {id: 'PERSON_ID'})-[r]-(t)
WHERE NOT type(r) = 'MENTIONS'
RETURN n, r, t
'''

# %% [markdown]
# # Traditional vs Hybrid Retrieval (GraphRAG)
# Enhancing RAG with Graph-based retrieval

# %% [markdown]
# ## Unstructured data retriever
# Semantic search through vector embeddings and vector search. The `Neo4jVector.from_existing_graph` method adds vector retrieval to documents. It configures vector search indexes for a retrieval approach.

# %%
# Create the vector index from the graph 
vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    search_type="vector",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding",
)
# Out:
# Failed to write data to connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687)))

# %%
# Cipher query to check embeddings generated
'''
MATCH (n:Document)
RETURN n.text, n.embedding
LIMIT 5
'''
# Out:
# '\nMATCH (n:Document)\nRETURN n.text, n.embedding\nLIMIT 5\n'

# %%
vector_index.similarity_search("1MDB")
# Out:
# [Document(metadata={'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, whil ...
#  Document(metadata={'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, whil ...
#  Document(metadata={'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, whil ...
#  Document(metadata={'summary': 'The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scandal\'s global scope implicated institutions and individuals in politics, banking, and entertainment, and led to criminal investigations in a number of nations. The 1MDB scandal has been described as "one of the world\'s greatest financial scandals" and declared by the United States Department of Justice as the "largest kleptocracy case to date" in 2016.\nA 2015 document leak reported in The Edge, Sarawak Report, and The Wall Street Journal showed that Malaysia\'s then-Prime Minister Najib Razak had channeled over RM 2.67 billion (about US$700 million) into his personal bank accounts from 1MDB, a government-run strategic development company. The alleged mastermind of the scheme, Jho Low, was central in the movement of 1MDB funds internationally through shell companies and offshore bank accounts. As of 2018, the U.S. Department of Justice found that Low and other conspirators including officials from Malaysia, Saudi Arabia and the United Arab Emirates diverted  more than US$4.5 billion from 1MDB. These funds were used to purchase luxury items and properties, including superyacht Equanimity, and finance the American film company Red Granite Pictures and the production of The Wolf of Wall Street and other films. 1MDB funds supported lavish lifestyles for Low, Najib and his wife Rosmah Mansor, and established Najib\'s stepson Riza Aziz in Hollywood. Attempts were also made for embezzled funds to be put towards political donations and lobbying in the United States.\nThe revelations became a major political scandal in Malaysia, triggering protests and backlash. After several Malaysian investigations were opened, Najib responded by dismissing several of his critics from government positions, including his deputy Muhyiddin Yassin and attorney-general Abdul Gani Patail. Charges against Najib were subsequently dismissed. Among Najib\'s critics was former ally and Malaysia\'s fourth Prime Minister Mahathir Mohamad, who chaired the Malaysian Citizens\' Declaration, bringing together political figures and other organisations in calling for Najib Razak\'s resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.\nOutside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.\nAfter the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, whil ...

# %% [markdown]
# ## Graph retriever
# The graph retriever starts by identifying relevant entities in the input. For simplicity, we instruct the LLM to identify people, organizations, and locations. To achieve this, we will use LCEL with the `with_structured_output` method to achieve this.
#
# LCEL stands for "Language Chain Extraction Language". In this case, the prompt is chained to the LLM, and the LLM is expected to produce a structured output adhering to the Entities class

# %%
# Just creating index for node entities
graph.query(
    "CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")

# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""
    names: List[str] = Field(
        ...,
        description="All the person, organization, or business entities that "
        "appear in the text",
    )

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting organization and person entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

# Extract entities from text
entity_chain = prompt | llm.with_structured_output(Entities)

# %% [markdown]
# ### Test Graph retriever to detect entities in the question

# %%
entity_chain.invoke({"question": "What scandal is Najib Razak known for in 1MDB?"})
# Out:
# Entities(names=['Najib Razak', '1MDB'])

# %% [markdown]
# ### Define query generation function
# Now that we can detect entities in the question, let's use a full-text index to map them to the knowledge graph.
# First, we define a full-text index and a function that will generate full-text queries that allow a bit of misspelling.

# %%
def generate_full_text_query(input: str) -> str:
    """
    Generate a full-text search query for a given input string.

    This function constructs a query string suitable for a full-text search.
    It processes the input string by splitting it into words and appending a
    similarity threshold (~2 changed characters) to each word, then combines
    them using the AND operator. Useful for mapping entities from user questions
    to database values, and allows for some misspelings.
    """
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# Fulltext index query
def structured_retriever(question: str) -> str:
    """
    Collects the neighborhood of entities mentioned
    in the question
    """
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              WITH node
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              WITH node
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

# %% [markdown]
# The `structured_retriever` function starts by detecting entities in the user question. Next, it iterates over the detected entities and uses a Cypher template to retrieve the neighborhood of relevant nodes.

# %%
print(structured_retriever("Who is Najib Razak and what is 1MDB?"))
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Najib Razak - MEMBER -> Umno
# Najib Razak - COLLABORATED -> Jho Low
# Najib Razak - SPOUSE -> Rosmah Mansor
# Najib Razak - INVOLVED_IN -> 1Mdb Scandal
# Najib Razak - ASSOCIATED_WITH -> Jho Low
# Najib Razak - ESTABLISHED -> 1Malaysia Development Berhad
# Najib Razak - MARRIED_TO -> Rosmah Mansor
# Najib Razak - GUILTY_OF_CHARGES -> Src International
# Najib Razak - PRIME_MINISTER -> Malaysia
# Najib Razak - CHAIRMAN -> 1Mdb
# Najib Razak - JOINT_VENTURE -> Petrosaudi
# 1Mdb - AGREEMENT_DATE -> 31_December_2015
# 1Mdb - AUDITOR -> Deloitte_Malaysia
# 1Mdb - DEBTS_ACCUMULATED_BY -> Early_2015
# 1Mdb - PAID -> Aabar Investments Pjs
# 1Mdb - PURCHASED_ASSETS -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_TO -> Najib Razak
# 1Mdb - TRANSFERRED_FUNDS_TO -> Ambank
# 1Mdb - TRANSFERRED_FUNDS_TO -> Affin Bank
# 1Mdb - TRANSFERRED_FUNDS_TO -> British Virgin Islands-Registered Company
# 1Mdb - JOINT_VENTURE_AGREEMENT -> Dusable Capital Management Llc
# 1Mdb - CREATED_FUND -> Yurus Pe Fund
# 1Mdb - BOUGHT_OUT_STAKE -> Dusable Capital Management Llc
# 1Mdb - FUNDED_LIFESTYLE -> Low
# 1Mdb - FILED_WITH -> Companies Commission Of Malaysia
# 1Mdb - FUNDING -> Bandar_Malaysia
# 1Mdb - CONTRACT_AWARD -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - AGREEMENT_WITH -> Iskandar_Waterfront_Holdings
# 1Mdb - AGREEMENT_WITH -> China_Railway_Engineering_Corporation
# 1Mdb - STAKE_SALE -> Bandar_Malaysia
# 1Mdb - PAYMENT -> Aabar Investments Pjs
# 1Mdb - SACKED -> Arul Kanda
# 1Mdb - SACKED_ON -> 28 June 2018
# 1Mdb - LINKED_TO -> Najib Razak
# 1Mdb - MADE_PURCHASES_THROUGH -> Genting Group
# 1Mdb - TRANSFERRED_MONEY_TO -> Ambank
# 1Mdb - TRANSFERRED_MONEY_TO -> Affin Bank
# 1Mdb - TRANSFERRED_MONEY_TO -> British Virgin Islands-Registered Company
# 1Mdb - TRANSFERRED_MONEY_THROUGH -> Falcon Bank
# 1Mdb - FILED_REPORT_WITH -> Companies Commission Of Malaysia
# 1Mdb - AWARDED_CONTRACT_DATE -> April_2013
# 1Mdb - CONTRACT_VALUE -> Rm_2.1_Billion
# 1Mdb - DEBT_AMOUNT -> Rm_42_Billion
# 1Mdb - OVERPRICED_PURCHASES -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_THROUGH -> Falcon Bank
# 1Mdb - OWED_FUNDS -> International Petroleum Investment Company
# 1Mdb - CONTRACT_AWARDEE -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - CONSORTIUM_MEMBER -> Iskandar_Waterfront_Holdings
# 1Mdb - CONSORTIUM_MEMBER -> China_Railway_Engineering_Corporation

# %% [markdown]
# ### Final retriever
# Bringing it all together, combine the unstructured and graph retriever to create the final context that will be passed to an LLM.

# %%
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f"""Structured data:
{structured_data}
Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    print(final_data)
    return final_data

# %% [markdown]
# ### Defining the RAG chain
#
# Now that we have successfully implemented the RAG retrieval component above, let's add query rewriting that allows conversational follow up questions.
#
# Chat history and user question is sent to LLM to be "summarised" as a condensed question

# %%
# Condense a chat history and follow-up question into a standalone question
_template = """Given the following conversation and a follow up question, rephrase the follow up question to be a standalone question,
in its original language.
Chat History:
{chat_history}
Follow Up Input: {question}
Standalone question:"""
CONDENSE_QUESTION_PROMPT = PromptTemplate.from_template(_template)

def _format_chat_history(chat_history: List[Tuple[str, str]]) -> List:
    buffer = []
    for human, ai in chat_history:
        buffer.append(HumanMessage(content=human))
        buffer.append(AIMessage(content=ai))
    return buffer

_search_query = RunnableBranch(
    # If input includes chat_history, we condense it with the follow-up question
    (
        RunnableLambda(lambda x: bool(x.get("chat_history"))).with_config(
            run_name="HasChatHistoryCheck"
        ),  # Condense follow-up question and chat into a standalone_question
        RunnablePassthrough.assign(
            chat_history=lambda x: _format_chat_history(x["chat_history"])
        )
        | CONDENSE_QUESTION_PROMPT
        | ChatOpenAI(temperature=0)
        | StrOutputParser(),
    ),
    # Else, we have no chat history, so just pass through the question
    RunnableLambda(lambda x : x["question"]),
)

# %% [markdown]
# ### Defining the prompt
# Next, we introduce a prompt that leverages the context provided by the integrated hybrid (Graph + Vector Search) retriever to produce the response, completing the implementation of the RAG chain.
#
# If there is any chat history, it is summarised first using _search_query, and then piped to retriever
# * Graph query: cipher query to retrieve relationships of the entity from question
# * Semantic search: vector search the embeddings to retrieve context

# %%
template = """Answer the question based only on the following context:
{context}

Question: {question}
Use natural language and be concise. If you don't know the answer, you can say "I don't know." 
Answer:"""
prompt = ChatPromptTemplate.from_template(template)

chain = (
    RunnableParallel(
        {
            # if there is any chat history, it is summarised first using _search_query, and then piped to retriever
            # retriever uses both graph query to retrieve relationships of the entity from question
            # and vector search the embeddings to retrieve context 
            "context": _search_query | retriever,
            "question": RunnablePassthrough(),
        }
    )
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ### Test the hybrid RAG implementation

# %%
chain.invoke({"question": "How is Jho Low related to Najib?"})
# Out:
# Search query: Who should be responsible for 1MDB scandal?
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Structured data:
# 1Mdb - REPORTED_TO -> Companies Commission Of Malaysia
# 1Mdb - RELATED_TO -> Src International
# 1Mdb - ADVISED_BY -> Ernst & Young
# 1Mdb - FUNDED -> Red Granite Pictures
# 1Mdb - CAUSE_CRISIS_OF_CONFIDENCE -> Malaysia
# 1Mdb - DEBT_INVOLVEMENT -> Goldman Sachs
# 1Mdb - JOINT_VENTURE -> Petrosaudi International
# 1Mdb - RAISED_FUNDS -> Rm_3.5_Billion
# 1Mdb - AUDITED_BY -> Kpmg
# 1Mdb - VALUED_BY -> Deloitte
# 1Mdb - CONTRACT_AWARD_DATE -> April_2013
# 1Mdb - AWARDED_CONTRACT -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - AGREEMENT_DATE -> 31_December_2015
# 1Mdb - AUDITOR -> Deloitte_Malaysia
# 1Mdb - DEBTS_ACCUMULATED_BY -> Early_2015
# 1Mdb - PAID -> Aabar Investments Pjs
# 1Mdb - PURCHASED_ASSETS -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_TO -> Najib Razak
# 1Mdb - TRANSFERRED_FUNDS_TO -> Ambank
# 1Mdb - TRANSFERRED_FUNDS_TO -> Affin Bank
# 1Mdb - TRANSFERRED_FUNDS_TO -> British Virgin Islands-Registered Company
# 1Mdb - JOINT_VENTURE_AGREEMENT -> Dusable Capital Management Llc
# 1Mdb - CREATED_FUND -> Yurus Pe Fund
# 1Mdb - BOUGHT_OUT_STAKE -> Dusable Capital Management Llc
# 1Mdb - FUNDED_LIFESTYLE -> Low
# 1Mdb - FILED_WITH -> Companies Commission Of Malaysia
# 1Mdb - FUNDING -> Bandar_Malaysia
# 1Mdb - CONTRACT_AWARD -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - AGREEMENT_WITH -> Iskandar_Waterfront_Holdings
# 1Mdb - AGREEMENT_WITH -> China_Railway_Engineering_Corporation
# 1Mdb - STAKE_SALE -> Bandar_Malaysia
# 1Mdb - PAYMENT -> Aabar Investments Pjs
# 1Mdb - SACKED -> Arul Kanda
# 1Mdb - SACKED_ON -> 28 June 2018
# 1Mdb - LINKED_TO -> Najib Razak
# 1Mdb - MADE_PURCHASES_THROUGH -> Genting Group
# 1Mdb - TRANSFERRED_MONEY_TO -> Ambank
# 1Mdb - TRANSFERRED_MONEY_TO -> Affin Bank
# 1Mdb - TRANSFERRED_MONEY_TO -> British Virgin Islands-Registered Company
# 1Mdb - TRANSFERRED_MONEY_THROUGH -> Falcon Bank
# 1Mdb - FILED_REPORT_WITH -> Companies Commission Of Malaysia
# 1Mdb - AWARDED_CONTRACT_DATE -> April_2013
# 1Mdb - CONTRACT_VALUE -> Rm_2.1_Billion
# 1Mdb - DEBT_AMOUNT -> Rm_42_Billion
# 1Mdb - OVERPRICED_PURCHASES -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_THROUGH -> Falcon Bank
# 1Mdb - OWED_FUNDS -> International Petroleum Investment Company
# 1Mdb - CONTRACT_AWARDEE -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - CONSORTIUM_MEMBER -> Iskandar_Waterfront_Holdings
# 1Mdb - CONSORTIUM_MEMBER -> China_Railway_Engineering_Corporation
# Unstructured data:
#
# text:  together political figures and other organisations in calling for Najib Razak's resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.
# Outside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.
# After the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, while alleged mastermind Jho Low, by then an international fugitive, was charged with money laundering. Najib was subsequently found guilty of seven charges connected to SRC International, a 1MDB subsidiary, and was sentenced to twelve years' imprisonment.
# In September 2020, the alleged amount stolen from 1MDB was estimated to be US$4.5 billion and a Malaysian government report listed 1MDB's outstanding debts to be at US$7.8 billion. The government has assumed 1MDB's debts, which includes 30-year bonds due in 2039. In August 2021, the United States had recovered and returned a total of US$1.2 billion of 1MDB funds misappropriated within its jurisdiction, joining countries such as Singapore and several others which have also initiated recovery or that have already repatriated smaller recovered amounts.
#
#
# == Background, key perpetrators ==
#
# Najib Razak became Prime Minister of Malaysia in 2009#Document
# text: The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scand
# Internet access was blocked by the Malaysian Communications and Multimedia Commission (MCMC), to websites including Medium.com, a social journalism platform over just a single article posted by Sarawak Report. Another website, Asia Sentinel, was blocked after carrying a Sarawak Report article related to MACC completing a probe that allegedly resulted in 37 charges being drawn up against Najib. The Malaysian Insider was also blocked and its journalists investigated for carrying a report alleging that the MACC had found enough evidence in its investigations into Najib to charge him for corruption. Blocks were removed shortly after the handover of power from Najib's government in the 2018 general election.
#
#
# === Ramifications and debt restructuring default ===
# The Malaysian Public Accounts Committee
# 'The 1MDB scandal involved multiple individuals and entities, but key figures include Najib Razak, the former Prime Minister of Malaysia, and Jho Low, who is alleged to be the mastermind behind the embezzlement of funds. Additionally, institutions like Goldman Sachs were implicated in the scandal. Responsibility is shared among these individuals and entities involved in the misappropriation and mismanagement of 1MDB funds.'

# %%
chain.invoke(
    {
        "question": "Was he also arrested?",
        "chat_history": [("How is Jho Low related to Najib?", "Jho Low is associated with Najib Razak through collaboration and ties. Jho Low collaborated with Najib in the 1MDB scheme and has ties to him.")],
    }
)
# Out:
# Search query: Was Jho Low also arrested?
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL (node, node) { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Structured data:
# Jho Low - SUPPORTED -> 1Malaysia Development Berhad
# Jho Low - COLLABORATED -> Petrosaudi
# Jho Low - LAWSUIT -> Doj
# Jho Low - ASSOCIATED_WITH -> Fugees
# Jho Low - SETTLEMENT -> Doj
# Jho Low - CHARGED_WITH -> Money Laundering
# Jho Low - FUNDED -> 2012 Presidential Election
# Jho Low - PURCHASED_WITH_STOLEN_FUNDS -> Equanimity
# Jho Low - PASSPORT_REVOKED_BY -> Cypriot Cabinet
# Jho Low - INVESTIGATION -> 1Mdb
# Jho Low - MISAPPROPRIATED_FUNDS -> 1Mdb
# Jho Low - CHARGED_WITH_MONEY_LAUNDERING -> 1Mdb
# Jho Low - MISAPPROPRIATION -> 1Mdb
# Jho Low - CHARGED -> Doj
# Jho Low - MISAPPROPRIATED_FUNDS_FROM -> 1Mdb
# Jho Low - FORFEITED_ASSETS_TO -> Doj
# Low Taek Jho - CONSULTED -> 1Mdb
# Low Taek Jho - SIPHONED_FUNDS -> Good Star Ltd
# Low Taek Jho - HAS_TIES -> Najib Razak
# Low Taek Jho - SIPHONED_FUNDS_THROUGH -> Good Star Ltd
# Najib Razak - COLLABORATED -> Jho Low
# Najib Razak - ASSOCIATED_WITH -> Jho Low
# Us Department Of Justice - INVESTIGATED -> Jho Low
# 1Malaysia Development Berhad Scandal - INVOLVES -> Jho Low
# Roger Ng - INTRODUCED -> Jho Low
# Khairuddin Abu Hassan - FILED_POLICE_REPORT -> Jho Low
# Government - ISSUED_ARREST_WARRANT -> Jho Low
# Home Ministry - SEARCHING -> Jho Low
# Najib Razak - ARREST_WARRANT -> Jho Low
# Government - ARREST_WARRANT -> Jho Low
# Malaysian Police - FILED_CRIMINAL_CHARGES -> Jho Low
# Attorney-General Chambers Of Malaysia - FILED_CRIMINAL_CHARGES -> Jho Low
# Former Kedah Menteri Besar Mukhriz Mahathir resigned his office on 3 February 2016, saying he did so because he had been told by Najib Razak that he was in the wrong by criticising him and 1MDB publicly. Four months later, in June, Mukhriz was expelled from UMNO. His father, Mahathir Mohamad, who had been Malaysia's fourth prime minister and who had been a Najib supporter since Najib assumed office, withdrew his support and quit UMNO later that same month.
# Opposition member of parliament Rafizi Ramli was arrested and charged under the Official Secrets Act by the police and the government for leaking information about the Auditor General's report on 1MDB.
# The Home Ministry stated that they and Interpol had been unsuccessful in locating various individuals linked to 1MDB to help in facilitating their investigations, including business tycoon Jho Low, 1MDB's former senior executives Casey Tang Keng Chee and Jasmine Loo Ai Swan, SRC International managing director Nik Faisal Ariff Kamil, and Deutsche Bank country manager Yusof Annuar Yaacob.
# Internet access was blocked by the Malaysian Communications and Multimedia Commission (MCMC), to websites including Medium.com, a social journalism platform over just a single article posted by Sarawak Report. Another website, Asia Sentinel, was blocked after carrying a Sarawak Report article related to MACC completing a probe that allegedly resulted in 37 charges being drawn up against Najib. The Malaysian Insider was also blocked and its journalists investigated for carrying a report alleging that the MACC had found enough evidence in its investigations into Najib to charge him for corruption. Blocks were removed shortly after the handover of power from Najib's government in the 2018 general election.
#
#
# === Ramifications and debt restructuring default ===
# The Malaysian Public Accounts Committee
# 'Jho Low was not arrested. The Home Ministry and Interpol were unsuccessful in locating him, and he remains a fugitive.'

# %% [markdown]
# ## Baseline RAG
#
# The retriever is written without graph query. Just vector search

# %%
def traditional_retriever(question: str):
    print(f"Search query: {question}")
    unstructured_data = [el.page_content for el in vector_index.similarity_search(question)]
    final_data = f"""Unstructured data:
{"#Document ". join(unstructured_data)}
    """
    print(final_data)
    return final_data

# %%
template = """Answer the question based only on the following context:
{context}

Question: {question}
Use natural language and be concise. If you don't know the answer, you can say "I don't know." 
Answer:"""
prompt = ChatPromptTemplate.from_template(template)

traditional_chain = (
    RunnableParallel(
        {
            "context": _search_query | traditional_retriever,
            "question": RunnablePassthrough(),
        }
    )
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ## Let's compare...

# %%
# Question asked to RAG
traditional_chain.invoke({"question": "How is Mahathir connected to Najib through the 1MDB scandal? Please explain as indepth as possible in 500 words."})
# Out:
# Search query: How is Mahathir connected to Najib through the 1MDB scandal? Please explain as indepth as possible in 500 words.
# Unstructured data:
#
# text:  together political figures and other organisations in calling for Najib Razak's resignation or removal. The Malaysian Conference of Rulers called for prompt investigation of the scandal, saying that it was causing a crisis of confidence in Malaysia.
# Outside of Malaysia, investigations into financial and criminal activity relating to 1MDB opened in at least six countries. According to its publicly filed accounts, 1MDB had nearly RM 42 billion (US$11.73 billion) in debt by 2015. Some of this debt resulted from a $3 billion state-guaranteed 2013 bond issue led by the American investment bank Goldman Sachs, which had been reported to have received fees of up to $300 million for the deal, although the bank disputes this figure. Nevertheless, Goldman Sachs was charged under the Foreign Corrupt Practices Act and agreed to pay over $2.9 billion in a settlement with the U.S. Department of Justice (DOJ). American rapper Pras, former Goldman Sachs chairman Tim Leissner and fundraiser Elliott Broidy were among those charged in the United States in connection with 1MDB.
# After the 2018 election, the newly elected prime minister, Mahathir Mohamad, reopened Malaysian investigations into the scandal. The Malaysian Immigration Department barred Najib and 11 others from leaving the country, while the police seized more than 500 handbags and 12,000 pieces of jewellery estimated to be worth US$270 million from property linked to Najib, the largest seizure of goods in Malaysian history. Najib was later charged with criminal breach of trust, money laundering and abuse of power, while alleged mastermind Jho Low, by then an international fugitive, was charged with money laundering. Najib was subsequently found guilty of seven charges connected to SRC International, a 1MDB subsidiary, and was sentenced to twelve years' imprisonment.
# In September 2020, the alleged amount stolen from 1MDB was estimated to be US$4.5 billion and a Malaysian government report listed 1MDB's outstanding debts to be at US$7.8 billion. The government has assumed 1MDB's debts, which includes 30-year bonds due in 2039. In August 2021, the United States had recovered and returned a total of US$1.2 billion of 1MDB funds misappropriated within its jurisdiction, joining countries such as Singapore and several others which have also initiated recovery or that have already repatriated smaller recovered amounts.
#
#
# == Background, key perpetrators ==
#
# Najib Razak became Prime Minister of Malaysia in 2009#Document
# text: The 1Malaysia Development Berhad scandal, often referred to as the 1MDB scandal or just 1MDB, is an ongoing corruption, bribery and money laundering conspiracy in which the Malaysian sovereign wealth fund 1Malaysia Development Berhad (1MDB) was systematically embezzled, with assets diverted globally by the perpetrators of the scheme. Although it began in 2009 in Malaysia, the scand
ALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              WITH node\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION ALL\n              WITH node\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output LIMIT 50\n            "
# Structured data:
# Mahathir - FILED_LAWSUIT_AGAINST -> Najib Razak
# Mahathir Mohamad - REOPEN_INVESTIGATION -> 1Mdb
# Mahathir Mohamad - WITHDREW_SUPPORT -> Najib
# Mahathir Mohamad - QUIT -> Umno
# Mahathir Mohamad - CHAIR -> Malaysian Citizens' Declaration
# 1Malaysia Development Berhad Scandal - INVOLVES -> Mahathir Mohamad
# Pakatan Harapan - LED_BY -> Mahathir MohamadNooryana Najwa Najib - MET_WITH -> Tim Leissner
# Nooryana Najwa Najib - MET_WITH -> Roger Ng
# Nooryana Najwa Najib - APPLIED_FOR_JOB_AT -> Goldman Sachs Group Inc
# Nooryana Najwa Najib - APPLIED_FOR_JOB -> Goldman Sachs Group Inc
# Najib - OUSTED_IN -> 2018_General_Election
# Najib - FUNDS_DIVERTED_FROM -> 1Mdb
# Najib - OUSTER_RELATED -> Audit_Report
# Najib - SENTENCED_TO -> 12 Years' Jail
# Najib - FINED -> Rm 210 Million
# Najib - SPENT_MONEY_IN -> United States
# Najib - SPENT_MONEY_IN -> Singapore
# Najib - SPENT_MONEY_IN -> Italy
# Macc - INVESTIGATED -> Najib
# Tony Pua - QUESTIONED -> Najib
# Macc - STATEMENT_ABOUT -> Najib
# Wan_Adnan_Wan_Mamat - CLAIMED_DONATION_FROM -> Najib
# Saudi_Foreign_Minister - AWARE_OF_DONATION -> Najib
# Adel_Al-Jubeir - AWARE_OF_DONATION -> Najib
# Turki_Bin_Abdullah_Al_Saud - DONATION_FROM -> Najib
# Mukhriz Mahathir - CRITICIZED -> Najib
# Mahathir Mohamad - WITHDREW_SUPPORT -> Najib
# Sarawak Report - PUBLISHED_ARTICLE_ABOUT -> Najib
# Sarawak Report - REPORTED -> Najib
# Saudi_Arabia - DONATION_TO -> Najib
# Macc - STATEMENT_ABOUT_DONATION -> Najib
# Attorney-General - STATEMENT_ABOUT_DONATION -> Najib
# Mohamad_Apandi_Ali - STATEMENT_ABOUT_DONATION -> Najib
# Wsj_Finance_Editor - STATEMENT_ABOUT_DONATION -> Najib
# Ken_Brown - STATEMENT_ABOUT_DONATION -> Najib
# Abc_News - INTERVIEW_ABOUT_DONATION -> Najib
# Sarawak Report - ALLEGED_CHARGES -> Najib
# 28 July 2020 - DATE_OF_CONVICTION -> Najib
# Court Of Appeal - UPHELD_CONVICTION -> Najib
# Federal Court - UPHELD_CONVICTION -> Najib
# Wan_Adnan_Wan_Mamat - CLAIMED_DONATION_FROM_SAUDI_ARABIA -> Najib
# Muslim_Community_Philippines - RECEIVED_SIMILAR_DONATIONS -> Najib
# Muslim_Community_Thailand - RECEIVED_SIMILAR_DONATIONS -> Najib
# Adel_Al-Jubeir - ACKNOWLEDGED_DONATION -> Najib
# Mohamad_Apandi_Ali - CONFIRMED_DONATION_FROM_TURKI_BIN_ABDULLAH_AL_SAUD -> Najib
# Ken_Brown - DISPUTED_DONATION_ORIGIN -> Najib1Mdb - REPORTED_TO -> Companies Commission Of Malaysia
# 1Mdb - RELATED_TO -> Src International
# 1Mdb - ADVISED_BY -> Ernst & Young
# 1Mdb - FUNDED -> Red Granite Pictures
# 1Mdb - CAUSE_CRISIS_OF_CONFIDENCE -> Malaysia
# 1Mdb - DEBT_INVOLVEMENT -> Goldman Sachs
# 1Mdb - JOINT_VENTURE -> Petrosaudi International
# 1Mdb - RAISED_FUNDS -> Rm_3.5_Billion
# 1Mdb - AUDITED_BY -> Kpmg
# 1Mdb - VALUED_BY -> Deloitte
# 1Mdb - CONTRACT_AWARD_DATE -> April_2013
# 1Mdb - AWARDED_CONTRACT -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - AGREEMENT_DATE -> 31_December_2015
# 1Mdb - AUDITOR -> Deloitte_Malaysia
# 1Mdb - DEBTS_ACCUMULATED_BY -> Early_2015
# 1Mdb - PAID -> Aabar Investments Pjs
# 1Mdb - PURCHASED_ASSETS -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_TO -> Najib Razak
# 1Mdb - TRANSFERRED_FUNDS_TO -> Ambank
# 1Mdb - TRANSFERRED_FUNDS_TO -> Affin Bank
# 1Mdb - TRANSFERRED_FUNDS_TO -> British Virgin Islands-Registered Company
# 1Mdb - JOINT_VENTURE_AGREEMENT -> Dusable Capital Management Llc
# 1Mdb - CREATED_FUND -> Yurus Pe Fund
# 1Mdb - BOUGHT_OUT_STAKE -> Dusable Capital Management Llc
# 1Mdb - FUNDED_LIFESTYLE -> Low
# 1Mdb - FILED_WITH -> Companies Commission Of Malaysia
# 1Mdb - FUNDING -> Bandar_Malaysia
# 1Mdb - CONTRACT_AWARD -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - AGREEMENT_WITH -> Iskandar_Waterfront_Holdings
# 1Mdb - AGREEMENT_WITH -> China_Railway_Engineering_Corporation
# 1Mdb - STAKE_SALE -> Bandar_Malaysia
# 1Mdb - PAYMENT -> Aabar Investments Pjs
# 1Mdb - SACKED -> Arul Kanda
# 1Mdb - SACKED_ON -> 28 June 2018
# 1Mdb - LINKED_TO -> Najib Razak
# 1Mdb - MADE_PURCHASES_THROUGH -> Genting Group
# 1Mdb - TRANSFERRED_MONEY_TO -> Ambank
# 1Mdb - TRANSFERRED_MONEY_TO -> Affin Bank
# 1Mdb - TRANSFERRED_MONEY_TO -> British Virgin Islands-Registered Company
# 1Mdb - TRANSFERRED_MONEY_THROUGH -> Falcon Bank
# 1Mdb - FILED_REPORT_WITH -> Companies Commission Of Malaysia
# 1Mdb - AWARDED_CONTRACT_DATE -> April_2013
# 1Mdb - CONTRACT_VALUE -> Rm_2.1_Billion
# 1Mdb - DEBT_AMOUNT -> Rm_42_Billion
# 1Mdb - OVERPRICED_PURCHASES -> Genting Group
# 1Mdb - TRANSFERRED_FUNDS_THROUGH -> Falcon Bank
# 1Mdb - OWED_FUNDS -> International Petroleum Investment Company
# 1Mdb - CONTRACT_AWARDEE -> Perbadanan_Perwira_Harta_Malaysia
# 1Mdb - CONSORTIUM_MEMBER -> Iskandar_Waterfront_Holdings
# 1Mdb - CONSORTIUM_MEMBER -> China_Railway_Engineering_Corporation
